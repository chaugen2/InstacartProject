# %% [markdown]
# # Task 4.6 Continued

# %% [markdown]
# ## Question 3

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Create path to folder
path = r'/Users/caitlin/Documents/Instacart Basket Analysis 12.2021'

# %%
path
# Out:
# '/Users/caitlin/Documents/Instacart Basket Analysis 12.2021'

# %%
df_ords_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# ## Question 4

# %%
# Check shape of dataframe
df_ords_combined.shape
# Out:
# (32434489, 14)

# %% [markdown]
# The shape is the same as in the previous notebook (titled Task 4.6).

# %% [markdown]
# ## Question 5

# %%
# Import products data from CSV file
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
# Check headings of products dataframe
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Drop unnecessary columns
df_prods_1 = df_prods.drop(columns = ['Unnamed: 0'],)

# %% [markdown]
# I decided to do this after I kept getting the "Cannot use name of an existing column for indicator column" error message.

# %%
# Check new headings
df_prods_1.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# Check headings of combined orders dataframe
df_ords_combined.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  order_id  user_id eval_set  order_number  \
# 0           0             0   2539329        1    prior             1
# 1           0             0   2539329        1    prior             1
# 2           0             0   2539329        1    prior             1
# 3           0             0   2539329        1    prior             1
# 4           0             0   2539329        1    prior             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                   2                  8                     NaN
# 1                   2                  8                     NaN
# 2                   2                  8                     NaN
# 3                   2                  8                     NaN
# 4                   2                  8                     NaN
#
#    single_order  product_id  add_to_cart_order  reordered _merge
# 0          True         196                  1          0   both
# ...

# %% [markdown]
# The common column is product_id, so I will use that as they key.

# %%
# Drop unnecessary columns
df_ords_combined_1 = df_ords_combined.drop(columns = ['_merge','Unnamed: 0.1'],)

# %%
# Check for dropped values
df_ords_combined_1.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0           0   2539329        1    prior             1                   2
# 1           0   2539329        1    prior             1                   2
# 2           0   2539329        1    prior             1                   2
# 3           0   2539329        1    prior             1                   2
# 4           0   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  single_order  product_id  \
# 0                  8                     NaN          True         196
# 1                  8                     NaN          True       14084
# 2                  8                     NaN          True       12427
# 3                  8                     NaN          True       26088
# 4                  8                     NaN          True       26405
#
#    add_to_cart_order  reordered
# 0                  1          0
# ...

# %%
# Merge dataframes
df_merged_ords_prods = df_ords_combined_1.merge(df_prods_1, on = 'product_id', indicator = True)

# %%
df_merged_ords_prods.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0           0   2539329        1    prior             1                   2
# 1           1   2398795        1    prior             2                   3
# 2           2    473747        1    prior             3                   3
# 3           3   2254736        1    prior             4                   4
# 4           4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  single_order  product_id  \
# 0                  8                     NaN          True         196
# 1                  7                    15.0         False         196
# 2                 12                    21.0         False         196
# 3                  7                    29.0         False         196
# 4                 15                    28.0         False         196
#
#    add_to_cart_order  reordered product_name  aisle_id  department_id  prices  \
# ...

# %% [markdown]
# ## Question 6

# %%
# Confirm results using merge flag
df_merged_ords_prods['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# ## Question 7

# %%
# Export new dataframe
df_merged_ords_prods.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_projects_merged.pkl'))

# %% [markdown]
# I choose pickle because it is very large and because I don't want column issues.
